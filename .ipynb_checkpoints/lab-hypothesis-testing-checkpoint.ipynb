# %% [markdown]
# # Lab | Hypothesis Testing

# %% [markdown]
# **Objective**
#
# Welcome to the Hypothesis Testing Lab, where we embark on an enlightening journey through the realm of statistical decision-making! In this laboratory, we delve into various scenarios, applying the powerful tools of hypothesis testing to scrutinize and interpret data.
#
# From testing the mean of a single sample (One Sample T-Test), to investigating differences between independent groups (Two Sample T-Test), and exploring relationships within dependent samples (Paired Sample T-Test), our exploration knows no bounds. Furthermore, we'll venture into the realm of Analysis of Variance (ANOVA), unraveling the complexities of comparing means across multiple groups.
#
# So, grab your statistical tools, prepare your hypotheses, and let's embark on this fascinating journey of exploration and discovery in the world of hypothesis testing!

# %% [markdown]
# **Challenge 1**

# %% [markdown]
# In this challenge, we will be working with pokemon data. The data can be found here:
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv

# %%
#libraries
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/pokemon.csv")
df
# Out:
#                Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0         Bulbasaur    Grass  Poison  45      49       49       65       65
# 1           Ivysaur    Grass  Poison  60      62       63       80       80
# 2          Venusaur    Grass  Poison  80      82       83      100      100
# 3     Mega Venusaur    Grass  Poison  80     100      123      122      120
# 4        Charmander     Fire     NaN  39      52       43       60       50
# ..              ...      ...     ...  ..     ...      ...      ...      ...
# 795         Diancie     Rock   Fairy  50     100      150      100      150
# 796    Mega Diancie     Rock   Fairy  50     160      110      160      110
# 797  Hoopa Confined  Psychic   Ghost  80     110       60      150      130
# 798   Hoopa Unbound  Psychic    Dark  80     160       60      170      130
# 799       Volcanion     Fire   Water  80     110      120      130       90
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# - We posit that Pokemons of type Dragon have, on average, more HP stats than Grass. Choose the propper test and, with 5% significance, comment your findings.

# %%
"""
H0: HP stars in Dragon <= Grass
H1: HP stars in Dragon > Grass

"""

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(dragon_hp.var())
print(grass_hp.var())
# Out:
# 566.2217741935484
# 380.8962732919254

# %%
# Grab and divide dataset in those groups

dragon_hp = df[df["Type 1"] == "Dragon"]["HP"]
grass_hp = df[df["Type 1"] == "Grass"]["HP"]

# %%
# Test hypothesis (two-sample t-test independent)
# 95% trust:

alpha = 0.05

t_stat, p_value = st.ttest_ind(
    dragon_hp,
    grass_hp,
    equal_var=False,
    alternative="greater"
)

# %%
print("Dragon mean HP:", dragon_hp.mean())
print("Grass mean HP:", grass_hp.mean())
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# Dragon mean HP: 83.3125
# Grass mean HP: 67.27142857142857
# t-statistic: 3.3349632905124063
# p-value: 0.0007993609745420597

# %%
if p_value > alpha:
    print("We are not able to reject the null hypothesis")
else:
    print("We reject the null hypotesis")
# Out:
# We reject the null hypotesis

# %% [markdown]
# There is sufficient statistical evidence to conclude that Dragon-type Pokémon have a higher average HP than Grass-type Pokémon.

# %% [markdown]
# - We posit that Legendary Pokemons have different stats (HP, Attack, Defense, Sp.Atk, Sp.Def, Speed) when comparing with Non-Legendary. Choose the propper test and, with 5% significance, comment your findings.

# %%
"""
H0: HP Legendary Pokemons <> Regular Pokemons
H1: HP Legendary Pokemons = Regular Pokemons

"""

# %%
# Grab and divide dataset in those groups

legendary = df[df["Legendary"] == True]
non_legendary = df[df["Legendary"] == False]

# %%
print(legendary.shape)
print(non_legendary.shape)
# Out:
# (65, 11)
# (735, 11)

# %%
#Chose the variants columns for the hypothesis
stats_cols = ["HP", "Attack", "Defense", "Sp. Atk", "Sp. Def", "Speed"]

# %%
alpha = 0.05

for col in stats_cols:
    t_stat, p_value = st.ttest_ind(
        legendary[col],
        non_legendary[col],
        equal_var = False
    )
    print("\n------------")
    print("STAT:", col)
    print("Legendary mean:", legendary[col].mean())
    print("Non-Legendary mean:", non_legendary[col].mean())
    print("p-value:", p_value)

    if p_value > alpha:
        print("We are not able to reject the null hypothesis")
    else:
        print("We reject the null hypotesis")
"""
Why a t-test?

Because we are comparing the mean values of a numerical variable between 
two independent groups (Legendary vs Non-Legendary Pokémon).
"""
# Out:
# ------------
# STAT: HP
# Legendary mean: 92.73846153846154
# Non-Legendary mean: 67.18231292517007
# p-value: 1.0026911708035284e-13
# We reject the null hypotesis
#
# ------------
# STAT: Attack
# Legendary mean: 116.67692307692307
# Non-Legendary mean: 75.66938775510204
# p-value: 2.5203724492366553e-16
# We reject the null hypotesis
#
# ------------
# STAT: Defense
# Legendary mean: 99.66153846153846
# Non-Legendary mean: 71.55918367346939
# p-value: 4.8269984949193316e-11
# We reject the null hypotesis
#
# ------------
# STAT: Sp. Atk
# Legendary mean: 122.18461538461538
# Non-Legendary mean: 68.45442176870748
# p-value: 1.5514614112239705e-21
# We reject the null hypotesis
#
# ------------
# STAT: Sp. Def
# Legendary mean: 105.93846153846154
# Non-Legendary mean: 68.89251700680272
# p-value: 2.294932786405291e-15
# We reject the null hypotesis
#
# ------------
# STAT: Speed
# Legendary mean: 100.18461538461538
# Non-Legendary mean: 65.45578231292517
# ...

# %% [markdown]
# For all six statistics (HP, Attack, Defense, Sp. Atk, Sp. Def and Speed), the p-values are below 0.05. Therefore, we reject the null hypothesis in every case.
#
# There is strong statistical evidence that Legendary Pokémon have different average stats than Non-Legendary Pokémon.
#
# Additionally, the means are higher for Legendary Pokémon across all six statistics.m

# %% [markdown]
# **Challenge 2**

# %% [markdown]
# In this challenge, we will be working with california-housing data. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/california_housing.csv")
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# **We posit that houses close to either a school or a hospital are more expensive.**
#
# - School coordinates (-118, 34)
# - Hospital coordinates (-122, 37)
#
# We consider a house (neighborhood) to be close to a school or hospital if the distance is lower than 0.50.
#
# Hint:
# - Write a function to calculate euclidean distance from each house (neighborhood) to the school and to the hospital.
# - Divide your dataset into houses close and far from either a hospital or school.
# - Choose the propper test and, with 5% significance, comment your findings.

# %%
close_dist = 0.5 #or closer
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
#Euclidean distance

def euclidean_distance(lon1, lat1, lon2, lat2):
    return np.sqrt((lon1 - lon2)**2 + (lat1 - lat2)**2)

# %%
#Calculate the distance to the school and/or the hospital
school_lon = -118
school_lat = 34

hospital_lon = -122
hospital_lat = 37

# %%
df["distance_school"] = euclidean_distance(
    df["longitude"],
    df["latitude"],
    school_lon,
    school_lat
)

df["distance_hospital"] = euclidean_distance(
    df["longitude"],
    df["latitude"],
    hospital_lon,
    hospital_lat
)

# %%
#Create groups (close or far) - the school and/or the hospital

df["close"] = (
    (df["distance_school"]<0.5)
    |
    (df["distance_hospital"]<0.5)
)

# %%
df["close"].value_counts()
# Out:
# close
# False    10171
# True      6829
# Name: count, dtype: int64

# %%
#Separate new groups

close_houses = df[df["close"] == True]["median_house_value"]

far_houses = df[df["close"] == False]["median_house_value"]

# %%
print("Close mean:", close_houses.mean())
print("Far mean:", far_houses.mean())
# Out:
# Close mean: 246951.98213501245
# Far mean: 180678.44105790975

# %%
#Hypothesis

"""
H0: Mean house price of close houses <= Mean house value far houses
H1: Mean house price of close houses > Mean house value far houses

"""

#Independent test (We have a numerical variable, and from two different independent groups

# %%
#Test

t_stat, p_value = st.ttest_ind(
    close_houses,
    far_houses,
    equal_var=False,
    alternative="greater"
)

print(t_stat)
print(p_value)
# Out:
# 37.992330214201516
# 1.5032478884296307e-301

# %% [markdown]
# Since the p-value is significantly lower than 0.05, we reject the null hypothesis. There is strong statistical evidence that houses located close to either a school or a hospital have a higher average house value than houses located farther away.
